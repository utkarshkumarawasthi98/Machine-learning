# %% [markdown]
# <a href="https://colab.research.google.com/github/utkarshkumarawasthi98/Machine-learning/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Custom dataset -> 2 clusters

import numpy as np
import matplotlib.pyplot as plt

# Custom dataset
custom_data = np.array([
    [2.0, 10.0], [2.0, 6.0], [11.0, 11.0],
    [6.0, 9.0], [6.0, 4.0], [1.0, 2.0],
    [5.0, 10.0], [4.0, 9.0], [10.0, 12.0],
    [7.0, 5.0], [9.0, 11.0], [4.0, 6.0],
    [3.0, 10.0], [3.0, 8.0], [6.0, 11.0]
])

def initialize_centroids(data, k):
    np.random.seed(42)
    indices = np.random.choice(data.shape[0], k, replace=False)
    return data[indices]

def assign_clusters(data, centroids):
    distances = np.linalg.norm(data[:, np.newaxis] - centroids, axis=2)
    return np.argmin(distances, axis=1)

def update_centroids(data, labels, k):
    return np.array([data[labels == i].mean(axis=0) for i in range(k)])

def plot_iteration(data, centroids, labels, iteration):
    # Plot each cluster with different labels
    for cluster_id in range(centroids.shape[0]):
        cluster_points = data[labels == cluster_id]
        plt.scatter(cluster_points[:, 0], cluster_points[:, 1], label=f'Cluster {cluster_id+1}')

    # Plot centroids
    plt.scatter(centroids[:, 0], centroids[:, 1], s=300, c='red', marker='x', label='Centroid')

    plt.title(f"Iteration {iteration}")
    plt.legend()
    plt.show()

    print(f"Centroids after iteration {iteration}:\n{centroids}\n")

def kmeans(data, k, max_iterations=10):
    centroids = initialize_centroids(data, k)
    for iteration in range(max_iterations):
        labels = assign_clusters(data, centroids)
        plot_iteration(data, centroids, labels, iteration + 1)
        new_centroids = update_centroids(data, labels, k)
        if np.all(centroids == new_centroids):
            break
        centroids = new_centroids
    return centroids, labels

# Perform K-means clustering on the custom dataset with K=2 and plot each iteration
final_centroids, final_labels = kmeans(custom_data, 2)
print(f"Final centroids:\n{final_centroids}")

# Display the points belonging to each cluster
for cluster_id in range(final_centroids.shape[0]):
    cluster_points = custom_data[final_labels == cluster_id]
    print(f"\nPoints in cluster {cluster_id+1}:\n{cluster_points}")
# Out:
# Centroids after iteration 1:
# [[7. 5.]
#  [4. 6.]]
# Centroids after iteration 2:
# [[8.6 8.6]
#  [3.6 8.1]]
# Centroids after iteration 3:
# [[ 8.6 10. ]
#  [ 3.6  7.4]]
# Centroids after iteration 4:
# [[ 8.4 10.8]
#  [ 3.7  7. ]]
#
# Final centroids:
# [[ 8.4 10.8]
#  [ 3.7  7. ]]
#
# Points in cluster 1:
# [[11. 11.]
#  [ 6.  9.]
#  [10. 12.]
#  [ 9. 11.]
#  [ 6. 11.]]
#
# Points in cluster 2:
# [[ 2. 10.]
#  [ 2.  6.]
#  [ 6.  4.]
#  [ 1.  2.]
#  [ 5. 10.]
#  [ 4.  9.]
#  [ 7.  5.]
#  [ 4.  6.]
#  [ 3. 10.]
#  [ 3.  8.]]

# %%
# Custom dataset -> 4 cluster

import numpy as np
import matplotlib.pyplot as plt

# Custom dataset
custom_data = np.array([
    [2.0, 10.0], [2.0, 6.0], [11.0, 11.0],
    [6.0, 9.0], [6.0, 4.0], [1.0, 2.0],
    [5.0, 10.0], [4.0, 9.0], [10.0, 12.0],
    [7.0, 5.0], [9.0, 11.0], [4.0, 6.0],
    [3.0, 10.0], [3.0, 8.0], [6.0, 11.0]
])

def initialize_centroids(data, k):
    np.random.seed(42)
    indices = np.random.choice(data.shape[0], k, replace=False)
    return data[indices]

def assign_clusters(data, centroids):
    distances = np.linalg.norm(data[:, np.newaxis] - centroids, axis=2)
    return np.argmin(distances, axis=1)

def update_centroids(data, labels, k):
    return np.array([data[labels == i].mean(axis=0) for i in range(k)])

def plot_iteration(data, centroids, labels, iteration):
    # Plot each cluster with different labels
    for cluster_id in range(centroids.shape[0]):
        cluster_points = data[labels == cluster_id]
        plt.scatter(cluster_points[:, 0], cluster_points[:, 1], label=f'Cluster {cluster_id+1}')

    # Plot centroids
    plt.scatter(centroids[:, 0], centroids[:, 1], s=300, c='red', marker='x', label='Centroid')

    plt.title(f"Iteration {iteration}")
    plt.legend()
    plt.show()

    print(f"Centroids after iteration {iteration}:\n{centroids}\n")

def kmeans(data, k, max_iterations=10):
    centroids = initialize_centroids(data, k)
    for iteration in range(max_iterations):
        labels = assign_clusters(data, centroids)
        plot_iteration(data, centroids, labels, iteration + 1)
        new_centroids = update_centroids(data, labels, k)
        if np.all(centroids == new_centroids):
            break
        centroids = new_centroids
    return centroids, labels

# Perform K-means clustering on the custom dataset with K=4 and plot each iteration
final_centroids, final_labels = kmeans(custom_data, 4)
print(f"Final centroids:\n{final_centroids}")

# Display the points belonging to each cluster
for cluster_id in range(final_centroids.shape[0]):
    cluster_points = custom_data[final_labels == cluster_id]
    print(f"\nPoints in cluster {cluster_id+1}:\n{cluster_points}")
# Out:
# Centroids after iteration 1:
# [[ 7.  5.]
#  [ 4.  6.]
#  [ 2. 10.]
#  [ 3.  8.]]
# Centroids after iteration 2:
# [[ 8.6         8.6       ]
#  [ 2.33333333  4.66666667]
#  [ 3.66666667 10.33333333]
#  [ 4.5         9.        ]]
# Centroids after iteration 3:
# [[ 9.25        9.75      ]
#  [ 3.25        4.5       ]
#  [ 3.66666667 10.33333333]
#  [ 4.5         9.        ]]
# Centroids after iteration 4:
# [[10.         11.33333333]
#  [ 4.          4.6       ]
#  [ 3.66666667 10.33333333]
#  [ 4.5         9.        ]]
#
# Final centroids:
# [[10.         11.33333333]
#  [ 4.          4.6       ]
#  [ 3.66666667 10.33333333]
#  [ 4.5         9.        ]]
#
# Points in cluster 1:
# [[11. 11.]
#  [10. 12.]
#  [ 9. 11.]]
#
# Points in cluster 2:
# [[2. 6.]
#  [6. 4.]
#  [1. 2.]
#  [7. 5.]
#  [4. 6.]]
#
# Points in cluster 3:
# [[ 2. 10.]
#  [ 3. 10.]
#  [ 6. 11.]]
#
# Points in cluster 4:
# [[ 6.  9.]
#  [ 5. 10.]
#  [ 4.  9.]
#  [ 3.  8.]]

# %%
# IRIS dataset -> 2 clusters

import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# Load Iris dataset
iris = load_iris()
iris_data = iris.data[:, :2]  # Using only the first two features for simplicity

def initialize_centroids(data, k):
    np.random.seed(42)
    indices = np.random.choice(data.shape[0], k, replace=False)
    return data[indices]

def assign_clusters(data, centroids):
    distances =dont label centroid 1 and centroid 2 just make oine legend as centroid np.linalg.norm(data[:, np.newaxis] - centroids, axis=2)
    return np.argmin(distances, axis=1)

def update_centroids(data, labels, k):
    return np.array([data[labels == i].mean(axis=0) for i in range(k)])

def plot_iteration(data, centroids, labels, iteration):
    # Plot each cluster with different labels
    for cluster_id in range(centroids.shape[0]):
        cluster_points = data[labels == cluster_id]
        plt.scatter(cluster_points[:, 0], cluster_points[:, 1], label=f'Cluster {cluster_id+1}')

    # Plot centroids
    plt.scatter(centroids[:, 0], centroids[:, 1], s=300, c='red', marker='x', label='Centroid')

    plt.title(f"Iteration {iteration}")
    plt.legend()
    plt.xlabel('Feature 1')
    plt.ylabel('Feature 2')
    plt.show()

    print(f"Centroids after iteration {iteration}:\n{centroids}\n")

def kmeans(data, k, max_iterations=10):
    centroids = initialize_centroids(data, k)
    for iteration in range(max_iterations):
        labels = assign_clusters(data, centroids)
        plot_iteration(data, centroids, labels, iteration + 1)
        new_centroids = update_centroids(data, labels, k)
        if np.all(centroids == new_centroids):
            break
        centroids = new_centroids
    return centroids, labels

# Perform K-means clustering on the Iris dataset with K=2 and plot each iteration
final_centroids, final_labels = kmeans(iris_data, 2)
print(f"Final centroids:\n{final_centroids}")

# Display the points belonging to each cluster
for cluster_id in range(final_centroids.shape[0]):
    cluster_points = iris_data[final_labels == cluster_id]
    print(f"\nPoints in cluster {cluster_id+1}:\n{cluster_points}")
# Out:
# Centroids after iteration 1:
# [[6.1 2.8]
#  [5.7 3.8]]
# Centroids after iteration 2:
# [[6.247 2.861]
#  [5.036 3.45 ]]
# Centroids after iteration 3:
# [[6.3516129  2.90107527]
#  [5.01403509 3.3122807 ]]
# Centroids after iteration 4:
# [[6.38651685 2.90224719]
#  [5.05081967 3.28360656]]
# Centroids after iteration 5:
# [[6.43690476 2.92261905]
#  [5.08787879 3.22878788]]
# Centroids after iteration 6:
# [[6.4775     2.935     ]
#  [5.11857143 3.19714286]]
# Centroids after iteration 7:
# [[6.50779221 2.94285714]
#  [5.14246575 3.17808219]]
# Centroids after iteration 8:
# [[6.51842105 2.94868421]
#  [5.15       3.16891892]]
#
# Final centroids:
# [[6.51842105 2.94868421]
#  [5.15       3.16891892]]
#
# Points in cluster 1:
# [[7.  3.2]
#  [6.4 3.2]
#  [6.9 3.1]
#  [6.5 2.8]
#  [6.3 3.3]
#  [6.6 2.9]
#  [5.9 3. ]
#  [6.  2.2]
#  [6.1 2.9]
#  [6.7 3.1]
#  [5.8 2.7]
#  [6.2 2.2]
#  [5.9 3.2]
#  [6.1 2.8]
#  [6.3 2.5]
#  [6.1 2.8]
#  [6.4 2.9]
#  [6.6 3. ]
#  [6.8 2.8]
# ...

# %%
# IRIS dataset -> 4 clusters

import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# Load Iris dataset
iris = load_iris()
iris_data = iris.data[:, :2]  # Using only the first two features for simplicity

def initialize_centroids(data, k):
    np.random.seed(42)
    indices = np.random.choice(data.shape[0], k, replace=False)
    return data[indices]

def assign_clusters(data, centroids):
    distances = np.linalg.norm(data[:, np.newaxis] - centroids, axis=2)
    return np.argmin(distances, axis=1)

def update_centroids(data, labels, k):
    return np.array([data[labels == i].mean(axis=0) for i in range(k)])

def plot_iteration(data, centroids, labels, iteration):
    # Plot each cluster with different labels
    for cluster_id in range(centroids.shape[0]):
        cluster_points = data[labels == cluster_id]
        plt.scatter(cluster_points[:, 0], cluster_points[:, 1], label=f'Cluster {cluster_id+1}')

    # Plot centroids
    plt.scatter(centroids[:, 0], centroids[:, 1], s=300, c='red', marker='x', label='Centroid')

    plt.title(f"Iteration {iteration}")
    plt.legend()
    plt.xlabel('Feature 1')
    plt.ylabel('Feature 2')
    plt.show()

    print(f"Centroids after iteration {iteration}:\n{centroids}\n")

def kmeans(data, k, max_iterations=10):
    centroids = initialize_centroids(data, k)
    for iteration in range(max_iterations):
        labels = assign_clusters(data, centroids)
        plot_iteration(data, centroids, labels, iteration + 1)
        new_centroids = update_centroids(data, labels, k)
        if np.all(centroids == new_centroids):
            break
        centroids = new_centroids
    return centroids, labels

# Perform K-means clustering on the Iris dataset with K=4 and plot each iteration
final_centroids, final_labels = kmeans(iris_data, 4)
print(f"Final centroids:\n{final_centroids}")

# Display the points belonging to each cluster
for cluster_id in range(final_centroids.shape[0]):
    cluster_points = iris_data[final_labels == cluster_id]
    print(f"\nPoints in cluster {cluster_id+1}:\n{cluster_points}")
# Out:
# Centroids after iteration 1:
# [[6.1 2.8]
#  [5.7 3.8]
#  [7.7 2.6]
#  [6.  2.9]]
# Centroids after iteration 2:
# [[6.42222222 2.83111111]
#  [5.03958333 3.46875   ]
#  [7.43846154 3.13076923]
#  [5.65681818 2.81818182]]
# Centroids after iteration 3:
# [[6.42272727 2.93409091]
#  [5.01632653 3.45102041]
#  [7.31176471 3.12941176]
#  [5.595      2.68      ]]
# Centroids after iteration 4:
# [[6.38541667 2.95      ]
#  [5.01632653 3.45102041]
#  [7.31176471 3.12941176]
#  [5.55277778 2.63055556]]
# Centroids after iteration 5:
# [[6.366      2.952     ]
#  [5.01632653 3.45102041]
#  [7.31176471 3.12941176]
#  [5.53235294 2.60882353]]
# Centroids after iteration 6:
# [[6.35882353 2.94705882]
#  [5.01632653 3.45102041]
#  [7.31176471 3.12941176]
#  [5.51818182 2.60606061]]
#
# Final centroids:
# [[6.35882353 2.94705882]
#  [5.01632653 3.45102041]
#  [7.31176471 3.12941176]
#  [5.51818182 2.60606061]]
#
# Points in cluster 1:
# [[6.4 3.2]
#  [6.5 2.8]
#  [6.3 3.3]
#  [6.6 2.9]
# ...
